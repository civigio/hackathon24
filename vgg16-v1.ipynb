# %%
import numpy as np
import pandas as pd
import os
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
import tensorflow.keras.models as tkm
from keras.applications.vgg16 import VGG16
import tensorflow.keras.optimizers as tko
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255.,
                                   validation_split = 0.2)

test_datagen = ImageDataGenerator(rescale = 1.0/255.)

# %%
base_dir = "/kaggle/input/brain-tumor-classification-mri"
train_dir = "Training"
train_dir = os.path.join(base_dir, train_dir)

test_dir = "Testing"
test_dir = os.path.join(base_dir, test_dir)

# %%
train_generator = train_datagen.flow_from_directory(train_dir, 
                                                    batch_size = 20, 
                                                    class_mode = 'sparse', 
                                                    target_size = (224, 224), 
                                                    shuffle = True,
                                                    subset="training")

validation_generator = train_datagen.flow_from_directory(train_dir, 
                                                         batch_size = 20, 
                                                         class_mode = 'sparse', 
                                                         target_size = (224, 224), 
                                                         shuffle = True,
                                                         subset="validation")
# Out:
# Found 2297 images belonging to 4 classes.
# Found 573 images belonging to 4 classes.

# %%
test_generator = test_datagen.flow_from_directory(test_dir,  
                                                  batch_size = 20, 
                                                  class_mode = 'sparse', 
                                                  target_size = (224, 224))
# Out:
# Found 394 images belonging to 4 classes.

# %%
vgg16 = VGG16(weights='imagenet', 
              input_shape=(224, 224, 3),
              #classes=self.classes, 
              include_top=False)

for layer in vgg16.layers:
            layer.trainable = False
        
vgg16.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
x = layers.Flatten()(vgg16.output)

x = layers.Dense(512, activation='relu')(x)

x = layers.Dropout(0.5)(x)

x = layers.Dense(4, activation='softmax')(x)

model = tkm.Model(vgg16.input, x)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    12,845,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,562,308 (105.14 MB)
#  Trainable params: 12,847,620 (49.01 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %%
model.compile(optimizer = tko.RMSprop(learning_rate=0.0001), loss = 'crossentropy', metrics = ['acc'])
model.summary()

early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor the validation loss (log-loss)
    patience=50,            # Number of epochs with no improvement after which training will be stopped
    verbose=1,             # Print a message when early stopping is triggered
    restore_best_weights=True  # Restore the model weights from the epoch with the best loss
)

#vgghist = model.fit(train_generator, validation_data = validation_generator, steps_per_epoch = 100, epochs = 10)
vgghist = model.fit(train_generator, validation_data = validation_generator, epochs = 200, callbacks=[early_stopping])
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    12,845,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,562,308 (105.14 MB)
#  Trainable params: 12,847,620 (49.01 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/200
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725439499.764591    2742 service.cc:145] XLA service 0x7cbda8002eb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1725439499.764637    2742 service.cc:153]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1725439499.764641    2742 service.cc:153]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
#   1/115 ━━━━━━━━━━━━━━━━━━━━ 32:16 17s/step - acc: 0.2000 - loss: 2.0522
# I0000 00:00:1725439514.396378    2742 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 59s 366ms/step - acc: 0.5518 - loss: 1.3165 - val_acc: 0.6283 - val_loss: 1.0781
# Epoch 2/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 141ms/step - acc: 0.7796 - loss: 0.5389 - val_acc: 0.7173 - val_loss: 0.7015
# Epoch 3/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 144ms/step - acc: 0.8527 - loss: 0.3886 - val_acc: 0.6283 - val_loss: 0.9357
# Epoch 4/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 18s 151ms/step - acc: 0.8681 - loss: 0.3112 - val_acc: 0.7365 - val_loss: 0.7198
# Epoch 5/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - acc: 0.8851 - loss: 0.2828 - val_acc: 0.6806 - val_loss: 0.8078
# Epoch 6/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.8998 - loss: 0.2646 - val_acc: 0.7766 - val_loss: 0.7586
# Epoch 7/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9202 - loss: 0.1966 - val_acc: 0.7469 - val_loss: 0.7571
# Epoch 8/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9356 - loss: 0.1720 - val_acc: 0.7749 - val_loss: 0.8030
# Epoch 9/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - acc: 0.9471 - loss: 0.1376 - val_acc: 0.7592 - val_loss: 0.8230
# Epoch 10/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - acc: 0.9393 - loss: 0.1477 - val_acc: 0.8063 - val_loss: 0.6947
# Epoch 11/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9608 - loss: 0.1115 - val_acc: 0.7696 - val_loss: 0.7630
# Epoch 12/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 144ms/step - acc: 0.9531 - loss: 0.1210 - val_acc: 0.7784 - val_loss: 0.7957
# Epoch 13/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9692 - loss: 0.1031 - val_acc: 0.7749 - val_loss: 0.8745
# Epoch 14/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - acc: 0.9673 - loss: 0.0911 - val_acc: 0.7435 - val_loss: 1.0245
# Epoch 15/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9706 - loss: 0.0765 - val_acc: 0.7853 - val_loss: 0.7999
# Epoch 16/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9784 - loss: 0.0742 - val_acc: 0.7818 - val_loss: 0.7776
# Epoch 17/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 144ms/step - acc: 0.9747 - loss: 0.0603 - val_acc: 0.7661 - val_loss: 0.8940
# Epoch 18/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9713 - loss: 0.0696 - val_acc: 0.7993 - val_loss: 0.8558
# Epoch 19/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9863 - loss: 0.0422 - val_acc: 0.8010 - val_loss: 0.8247
# Epoch 20/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9851 - loss: 0.0491 - val_acc: 0.7958 - val_loss: 0.8960
# Epoch 21/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9801 - loss: 0.0554 - val_acc: 0.8010 - val_loss: 0.9356
# Epoch 22/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9820 - loss: 0.0459 - val_acc: 0.8185 - val_loss: 0.8540
# Epoch 23/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9856 - loss: 0.0398 - val_acc: 0.8045 - val_loss: 0.9574
# Epoch 24/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9795 - loss: 0.0570 - val_acc: 0.8010 - val_loss: 0.9244
# Epoch 25/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - acc: 0.9912 - loss: 0.0324 - val_acc: 0.7976 - val_loss: 0.9623
# Epoch 26/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9833 - loss: 0.0466 - val_acc: 0.8133 - val_loss: 0.8656
# Epoch 27/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9931 - loss: 0.0319 - val_acc: 0.8080 - val_loss: 0.9538
# Epoch 28/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9865 - loss: 0.0307 - val_acc: 0.8045 - val_loss: 1.0003
# Epoch 29/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9892 - loss: 0.0262 - val_acc: 0.7871 - val_loss: 1.1906
# Epoch 30/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9893 - loss: 0.0331 - val_acc: 0.7853 - val_loss: 1.0865
# Epoch 31/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9904 - loss: 0.0204 - val_acc: 0.7941 - val_loss: 1.0631
# Epoch 32/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 144ms/step - acc: 0.9919 - loss: 0.0254 - val_acc: 0.7592 - val_loss: 1.2582
# Epoch 33/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - acc: 0.9962 - loss: 0.0168 - val_acc: 0.7958 - val_loss: 1.0198
# Epoch 34/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - acc: 0.9959 - loss: 0.0133 - val_acc: 0.7993 - val_loss: 1.0590
# Epoch 35/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9941 - loss: 0.0193 - val_acc: 0.7766 - val_loss: 1.2419
# Epoch 36/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9948 - loss: 0.0179 - val_acc: 0.7784 - val_loss: 1.0412
# Epoch 37/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 144ms/step - acc: 0.9943 - loss: 0.0202 - val_acc: 0.8045 - val_loss: 1.1289
# Epoch 38/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9964 - loss: 0.0115 - val_acc: 0.8028 - val_loss: 1.1303
# Epoch 39/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9940 - loss: 0.0175 - val_acc: 0.7923 - val_loss: 1.2985
# Epoch 40/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9977 - loss: 0.0114 - val_acc: 0.7906 - val_loss: 1.1206
# Epoch 41/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9988 - loss: 0.0089 - val_acc: 0.7993 - val_loss: 1.1830
# Epoch 42/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9985 - loss: 0.0083 - val_acc: 0.8028 - val_loss: 1.1522
# Epoch 43/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9962 - loss: 0.0130 - val_acc: 0.8028 - val_loss: 1.2182
# Epoch 44/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9933 - loss: 0.0178 - val_acc: 0.8063 - val_loss: 1.1038
# Epoch 45/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9934 - loss: 0.0144 - val_acc: 0.8080 - val_loss: 1.1108
# Epoch 46/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9966 - loss: 0.0079 - val_acc: 0.8272 - val_loss: 1.1610
# Epoch 47/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9945 - loss: 0.0142 - val_acc: 0.7958 - val_loss: 1.2819
# Epoch 48/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9956 - loss: 0.0119 - val_acc: 0.8133 - val_loss: 1.1906
# Epoch 49/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9983 - loss: 0.0045 - val_acc: 0.8150 - val_loss: 1.1020
# Epoch 50/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9957 - loss: 0.0122 - val_acc: 0.7958 - val_loss: 1.2127
# Epoch 51/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9998 - loss: 0.0063 - val_acc: 0.8185 - val_loss: 1.0940
# Epoch 52/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9986 - loss: 0.0037 - val_acc: 0.8202 - val_loss: 1.1199
# Epoch 53/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - acc: 0.9988 - loss: 0.0041 - val_acc: 0.8115 - val_loss: 1.0741
# Epoch 54/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9975 - loss: 0.0108 - val_acc: 0.8045 - val_loss: 1.2786
# Epoch 55/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9979 - loss: 0.0080 - val_acc: 0.8098 - val_loss: 1.1723
# Epoch 56/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9994 - loss: 0.0039 - val_acc: 0.8150 - val_loss: 1.2360
# Epoch 57/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9986 - loss: 0.0058 - val_acc: 0.8080 - val_loss: 1.2620
# Epoch 58/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 0.9990 - loss: 0.0060 - val_acc: 0.8098 - val_loss: 1.1864
# Epoch 59/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 146ms/step - acc: 0.9946 - loss: 0.0082 - val_acc: 0.8150 - val_loss: 1.2627
# Epoch 60/200
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 17s 145ms/step - acc: 1.0000 - loss: 0.0017 - val_acc: 0.7836 - val_loss: 1.4911
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 10.

# %%
batches = 0
pred_class = []
y_bat = []
for x_batch, y_batch in test_generator:
    predictions = model.predict(x_batch)
    predicted_classes = predictions.argmax(axis=-1)
    pred_class.extend(predicted_classes)
    y_bat.extend(y_batch)
    batches += 1
    if batches > 394 / 20:
        break
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step

# %%
print(len(y_bat))
print(len(pred_class))
if len(y_bat)!=len(pred_class):
    print('ERROR!ERROR!ERROR!')
# Out:
# 394
# 394

# %%
# Calculate accuracy
print(f'Accuracy: {accuracy_score(y_bat, pred_class)}')
print('\n-------------\n')

# Print classification report
print(classification_report(y_bat, pred_class))
print('\n-------------\n')

# Print confusion matrix
cm = confusion_matrix(y_bat, pred_class, normalize='true')
print(cm)
# Out:
# Accuracy: 0.7106598984771574
#
# -------------
#
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.20      0.33       100
#          1.0       0.70      0.97      0.81       115
#          2.0       0.64      0.96      0.77       105
#          3.0       0.84      0.64      0.72        74
#
#     accuracy                           0.71       394
#    macro avg       0.78      0.69      0.66       394
# weighted avg       0.78      0.71      0.66       394
#
#
# -------------
#
# [[0.2        0.34       0.38       0.08      ]
#  [0.         0.97391304 0.02608696 0.        ]
#  [0.00952381 0.01904762 0.96190476 0.00952381]
#  [0.         0.16216216 0.2027027  0.63513514]]

# %%
import seaborn as sns
sns.heatmap(cm, annot=True, fmt='.2%', cmap="Greens")

pd.DataFrame(vgghist.history).plot(figsize=(8,5))
plt.grid()
plt.show()
